# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression 
from sklearn.neighbors import KNeighborsClassifier
from sklearn import tree
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.metrics import accuracy_score


import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv("/kaggle/input/iris-flower-dataset/IRIS.csv")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.head(10).style.background_gradient(cmap='rainbow')
# Out:
# <style type="text/css">
# #T_4fd8a_row0_col0, #T_4fd8a_row4_col1 {
#   background-color: #e6cd73;
#   color: #000000;
# }
# #T_4fd8a_row0_col1, #T_4fd8a_row4_col0, #T_4fd8a_row7_col0 {
#   background-color: #b2f396;
#   color: #000000;
# }
# #T_4fd8a_row0_col2, #T_4fd8a_row1_col2, #T_4fd8a_row4_col2, #T_4fd8a_row6_col2, #T_4fd8a_row8_col2 {
#   background-color: #01b3ec;
#   color: #f1f1f1;
# }
# #T_4fd8a_row0_col3, #T_4fd8a_row1_col3, #T_4fd8a_row2_col3, #T_4fd8a_row3_col3, #T_4fd8a_row4_col3, #T_4fd8a_row7_col3, #T_4fd8a_row8_col3 {
#   background-color: #2adddd;
#   color: #000000;
# }
# #T_4fd8a_row1_col0, #T_4fd8a_row3_col2, #T_4fd8a_row6_col1, #T_4fd8a_row7_col1, #T_4fd8a_row7_col2, #T_4fd8a_row9_col0, #T_4fd8a_row9_col2 {
#   background-color: #80ffb4;
#   color: #000000;
# }
# #T_4fd8a_row1_col1 {
#   background-color: #4e4dfc;
#   color: #f1f1f1;
# }
# #T_4fd8a_row2_col0, #T_4fd8a_row2_col1 {
#   background-color: #18cde4;
#   color: #000000;
# }
# #T_4fd8a_row2_col2, #T_4fd8a_row8_col0, #T_4fd8a_row8_col1, #T_4fd8a_row9_col3 {
#   background-color: #8000ff;
#   color: #f1f1f1;
# }
# #T_4fd8a_row3_col0, #T_4fd8a_row3_col1, #T_4fd8a_row6_col0, #T_4fd8a_row9_col1 {
#   background-color: #1996f3;
#   color: #f1f1f1;
# }
# #T_4fd8a_row5_col0, #T_4fd8a_row5_col1, #T_4fd8a_row5_col2, #T_4fd8a_row5_col3 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_4fd8a_row6_col3 {
#   background-color: #d4dd80;
#   color: #000000;
# }
# </style>
# <table id="T_4fd8a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4fd8a_level0_col0" class="col_heading level0 col0" >sepal_length</th>
#       <th id="T_4fd8a_level0_col1" class="col_heading level0 col1" >sepal_width</th>
#       <th id="T_4fd8a_level0_col2" class="col_heading level0 col2" >petal_length</th>
#       <th id="T_4fd8a_level0_col3" class="col_heading level0 col3" >petal_width</th>
#       <th id="T_4fd8a_level0_col4" class="col_heading level0 col4" >species</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4fd8a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4fd8a_row0_col0" class="data row0 col0" >5.100000</td>
#       <td id="T_4fd8a_row0_col1" class="data row0 col1" >3.500000</td>
#       <td id="T_4fd8a_row0_col2" class="data row0 col2" >1.400000</td>
#       <td id="T_4fd8a_row0_col3" class="data row0 col3" >0.200000</td>
#       <td id="T_4fd8a_row0_col4" class="data row0 col4" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_4fd8a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4fd8a_row1_col0" class="data row1 col0" >4.900000</td>
#       <td id="T_4fd8a_row1_col1" class="data row1 col1" >3.000000</td>
#       <td id="T_4fd8a_row1_col2" class="data row1 col2" >1.400000</td>
#       <td id="T_4fd8a_row1_col3" class="data row1 col3" >0.200000</td>
#       <td id="T_4fd8a_row1_col4" class="data row1 col4" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_4fd8a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4fd8a_row2_col0" class="data row2 col0" >4.700000</td>
#       <td id="T_4fd8a_row2_col1" class="data row2 col1" >3.200000</td>
#       <td id="T_4fd8a_row2_col2" class="data row2 col2" >1.300000</td>
#       <td id="T_4fd8a_row2_col3" class="data row2 col3" >0.200000</td>
#       <td id="T_4fd8a_row2_col4" class="data row2 col4" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_4fd8a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4fd8a_row3_col0" class="data row3 col0" >4.600000</td>
#       <td id="T_4fd8a_row3_col1" class="data row3 col1" >3.100000</td>
#       <td id="T_4fd8a_row3_col2" class="data row3 col2" >1.500000</td>
#       <td id="T_4fd8a_row3_col3" class="data row3 col3" >0.200000</td>
#       <td id="T_4fd8a_row3_col4" class="data row3 col4" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_4fd8a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4fd8a_row4_col0" class="data row4 col0" >5.000000</td>
#       <td id="T_4fd8a_row4_col1" class="data row4 col1" >3.600000</td>
#       <td id="T_4fd8a_row4_col2" class="data row4 col2" >1.400000</td>
#       <td id="T_4fd8a_row4_col3" class="data row4 col3" >0.200000</td>
#       <td id="T_4fd8a_row4_col4" class="data row4 col4" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_4fd8a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4fd8a_row5_col0" class="data row5 col0" >5.400000</td>
#       <td id="T_4fd8a_row5_col1" class="data row5 col1" >3.900000</td>
#       <td id="T_4fd8a_row5_col2" class="data row5 col2" >1.700000</td>
#       <td id="T_4fd8a_row5_col3" class="data row5 col3" >0.400000</td>
#       <td id="T_4fd8a_row5_col4" class="data row5 col4" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_4fd8a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4fd8a_row6_col0" class="data row6 col0" >4.600000</td>
#       <td id="T_4fd8a_row6_col1" class="data row6 col1" >3.400000</td>
#       <td id="T_4fd8a_row6_col2" class="data row6 col2" >1.400000</td>
#       <td id="T_4fd8a_row6_col3" class="data row6 col3" >0.300000</td>
#       <td id="T_4fd8a_row6_col4" class="data row6 col4" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_4fd8a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4fd8a_row7_col0" class="data row7 col0" >5.000000</td>
#       <td id="T_4fd8a_row7_col1" class="data row7 col1" >3.400000</td>
#       <td id="T_4fd8a_row7_col2" class="data row7 col2" >1.500000</td>
#       <td id="T_4fd8a_row7_col3" class="data row7 col3" >0.200000</td>
#       <td id="T_4fd8a_row7_col4" class="data row7 col4" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_4fd8a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4fd8a_row8_col0" class="data row8 col0" >4.400000</td>
#       <td id="T_4fd8a_row8_col1" class="data row8 col1" >2.900000</td>
#       <td id="T_4fd8a_row8_col2" class="data row8 col2" >1.400000</td>
#       <td id="T_4fd8a_row8_col3" class="data row8 col3" >0.200000</td>
#       <td id="T_4fd8a_row8_col4" class="data row8 col4" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_4fd8a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4fd8a_row9_col0" class="data row9 col0" >4.900000</td>
#       <td id="T_4fd8a_row9_col1" class="data row9 col1" >3.100000</td>
#       <td id="T_4fd8a_row9_col2" class="data row9 col2" >1.500000</td>
#       <td id="T_4fd8a_row9_col3" class="data row9 col3" >0.100000</td>
#       <td id="T_4fd8a_row9_col4" class="data row9 col4" >Iris-setosa</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df.tail(10).style.background_gradient(cmap='rainbow')
# Out:
# <style type="text/css">
# #T_50656_row0_col0, #T_50656_row4_col0, #T_50656_row5_col0 {
#   background-color: #ff8947;
#   color: #f1f1f1;
# }
# #T_50656_row0_col1, #T_50656_row0_col2, #T_50656_row1_col1 {
#   background-color: #d4dd80;
#   color: #000000;
# }
# #T_50656_row0_col3 {
#   background-color: #ff6d38;
#   color: #f1f1f1;
# }
# #T_50656_row1_col0, #T_50656_row3_col2, #T_50656_row4_col3, #T_50656_row8_col1 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_50656_row1_col2, #T_50656_row2_col2, #T_50656_row9_col2 {
#   background-color: #4856fb;
#   color: #f1f1f1;
# }
# #T_50656_row1_col3, #T_50656_row3_col3, #T_50656_row5_col3, #T_50656_row8_col3 {
#   background-color: #ecc86f;
#   color: #000000;
# }
# #T_50656_row2_col0, #T_50656_row6_col1, #T_50656_row6_col2, #T_50656_row9_col3 {
#   background-color: #8000ff;
#   color: #f1f1f1;
# }
# #T_50656_row2_col1, #T_50656_row5_col2, #T_50656_row7_col2 {
#   background-color: #10a2f0;
#   color: #f1f1f1;
# }
# #T_50656_row2_col3, #T_50656_row6_col3 {
#   background-color: #386df9;
#   color: #f1f1f1;
# }
# #T_50656_row3_col0 {
#   background-color: #ff4724;
#   color: #f1f1f1;
# }
# #T_50656_row3_col1, #T_50656_row4_col2 {
#   background-color: #ffa256;
#   color: #000000;
# }
# #T_50656_row4_col1 {
#   background-color: #ff562c;
#   color: #f1f1f1;
# }
# #T_50656_row5_col1, #T_50656_row7_col1, #T_50656_row9_col1 {
#   background-color: #9cfba4;
#   color: #000000;
# }
# #T_50656_row6_col0 {
#   background-color: #68fcc1;
#   color: #000000;
# }
# #T_50656_row7_col0 {
#   background-color: #c4e88a;
#   color: #000000;
# }
# #T_50656_row7_col3 {
#   background-color: #12c8e6;
#   color: #000000;
# }
# #T_50656_row8_col0 {
#   background-color: #3ae8d6;
#   color: #000000;
# }
# #T_50656_row8_col2 {
#   background-color: #62fbc4;
#   color: #000000;
# }
# #T_50656_row9_col0 {
#   background-color: #5247fc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_50656">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50656_level0_col0" class="col_heading level0 col0" >sepal_length</th>
#       <th id="T_50656_level0_col1" class="col_heading level0 col1" >sepal_width</th>
#       <th id="T_50656_level0_col2" class="col_heading level0 col2" >petal_length</th>
#       <th id="T_50656_level0_col3" class="col_heading level0 col3" >petal_width</th>
#       <th id="T_50656_level0_col4" class="col_heading level0 col4" >species</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50656_level0_row0" class="row_heading level0 row0" >140</th>
#       <td id="T_50656_row0_col0" class="data row0 col0" >6.700000</td>
#       <td id="T_50656_row0_col1" class="data row0 col1" >3.100000</td>
#       <td id="T_50656_row0_col2" class="data row0 col2" >5.600000</td>
#       <td id="T_50656_row0_col3" class="data row0 col3" >2.400000</td>
#       <td id="T_50656_row0_col4" class="data row0 col4" >Iris-virginica</td>
#     </tr>
#     <tr>
#       <th id="T_50656_level0_row1" class="row_heading level0 row1" >141</th>
#       <td id="T_50656_row1_col0" class="data row1 col0" >6.900000</td>
#       <td id="T_50656_row1_col1" class="data row1 col1" >3.100000</td>
#       <td id="T_50656_row1_col2" class="data row1 col2" >5.100000</td>
#       <td id="T_50656_row1_col3" class="data row1 col3" >2.300000</td>
#       <td id="T_50656_row1_col4" class="data row1 col4" >Iris-virginica</td>
#     </tr>
#     <tr>
#       <th id="T_50656_level0_row2" class="row_heading level0 row2" >142</th>
#       <td id="T_50656_row2_col0" class="data row2 col0" >5.800000</td>
#       <td id="T_50656_row2_col1" class="data row2 col1" >2.700000</td>
#       <td id="T_50656_row2_col2" class="data row2 col2" >5.100000</td>
#       <td id="T_50656_row2_col3" class="data row2 col3" >1.900000</td>
#       <td id="T_50656_row2_col4" class="data row2 col4" >Iris-virginica</td>
#     </tr>
#     <tr>
#       <th id="T_50656_level0_row3" class="row_heading level0 row3" >143</th>
#       <td id="T_50656_row3_col0" class="data row3 col0" >6.800000</td>
#       <td id="T_50656_row3_col1" class="data row3 col1" >3.200000</td>
#       <td id="T_50656_row3_col2" class="data row3 col2" >5.900000</td>
#       <td id="T_50656_row3_col3" class="data row3 col3" >2.300000</td>
#       <td id="T_50656_row3_col4" class="data row3 col4" >Iris-virginica</td>
#     </tr>
#     <tr>
#       <th id="T_50656_level0_row4" class="row_heading level0 row4" >144</th>
#       <td id="T_50656_row4_col0" class="data row4 col0" >6.700000</td>
#       <td id="T_50656_row4_col1" class="data row4 col1" >3.300000</td>
#       <td id="T_50656_row4_col2" class="data row4 col2" >5.700000</td>
#       <td id="T_50656_row4_col3" class="data row4 col3" >2.500000</td>
#       <td id="T_50656_row4_col4" class="data row4 col4" >Iris-virginica</td>
#     </tr>
#     <tr>
#       <th id="T_50656_level0_row5" class="row_heading level0 row5" >145</th>
#       <td id="T_50656_row5_col0" class="data row5 col0" >6.700000</td>
#       <td id="T_50656_row5_col1" class="data row5 col1" >3.000000</td>
#       <td id="T_50656_row5_col2" class="data row5 col2" >5.200000</td>
#       <td id="T_50656_row5_col3" class="data row5 col3" >2.300000</td>
#       <td id="T_50656_row5_col4" class="data row5 col4" >Iris-virginica</td>
#     </tr>
#     <tr>
#       <th id="T_50656_level0_row6" class="row_heading level0 row6" >146</th>
#       <td id="T_50656_row6_col0" class="data row6 col0" >6.300000</td>
#       <td id="T_50656_row6_col1" class="data row6 col1" >2.500000</td>
#       <td id="T_50656_row6_col2" class="data row6 col2" >5.000000</td>
#       <td id="T_50656_row6_col3" class="data row6 col3" >1.900000</td>
#       <td id="T_50656_row6_col4" class="data row6 col4" >Iris-virginica</td>
#     </tr>
#     <tr>
#       <th id="T_50656_level0_row7" class="row_heading level0 row7" >147</th>
#       <td id="T_50656_row7_col0" class="data row7 col0" >6.500000</td>
#       <td id="T_50656_row7_col1" class="data row7 col1" >3.000000</td>
#       <td id="T_50656_row7_col2" class="data row7 col2" >5.200000</td>
#       <td id="T_50656_row7_col3" class="data row7 col3" >2.000000</td>
#       <td id="T_50656_row7_col4" class="data row7 col4" >Iris-virginica</td>
#     </tr>
#     <tr>
#       <th id="T_50656_level0_row8" class="row_heading level0 row8" >148</th>
#       <td id="T_50656_row8_col0" class="data row8 col0" >6.200000</td>
#       <td id="T_50656_row8_col1" class="data row8 col1" >3.400000</td>
#       <td id="T_50656_row8_col2" class="data row8 col2" >5.400000</td>
#       <td id="T_50656_row8_col3" class="data row8 col3" >2.300000</td>
#       <td id="T_50656_row8_col4" class="data row8 col4" >Iris-virginica</td>
#     </tr>
#     <tr>
#       <th id="T_50656_level0_row9" class="row_heading level0 row9" >149</th>
#       <td id="T_50656_row9_col0" class="data row9 col0" >5.900000</td>
#       <td id="T_50656_row9_col1" class="data row9 col1" >3.000000</td>
#       <td id="T_50656_row9_col2" class="data row9 col2" >5.100000</td>
#       <td id="T_50656_row9_col3" class="data row9 col3" >1.800000</td>
#       <td id="T_50656_row9_col4" class="data row9 col4" >Iris-virginica</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.sample(10).style.background_gradient(cmap='rainbow')
# Out:
# <style type="text/css">
# #T_12446_row0_col0 {
#   background-color: #64fbc3;
#   color: #000000;
# }
# #T_12446_row0_col1, #T_12446_row2_col1, #T_12446_row3_col1, #T_12446_row8_col1 {
#   background-color: #ecc86f;
#   color: #000000;
# }
# #T_12446_row0_col2, #T_12446_row4_col3 {
#   background-color: #c4e88a;
#   color: #000000;
# }
# #T_12446_row0_col3 {
#   background-color: #ffa759;
#   color: #000000;
# }
# #T_12446_row1_col0, #T_12446_row4_col0 {
#   background-color: #9bfba5;
#   color: #000000;
# }
# #T_12446_row1_col1, #T_12446_row4_col1 {
#   background-color: #ff6d38;
#   color: #f1f1f1;
# }
# #T_12446_row1_col2 {
#   background-color: #ebca70;
#   color: #000000;
# }
# #T_12446_row1_col3, #T_12446_row6_col0, #T_12446_row6_col2, #T_12446_row6_col3, #T_12446_row9_col1 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_12446_row2_col0, #T_12446_row2_col2, #T_12446_row2_col3, #T_12446_row5_col1, #T_12446_row9_col0 {
#   background-color: #8000ff;
#   color: #f1f1f1;
# }
# #T_12446_row3_col0 {
#   background-color: #bced8f;
#   color: #000000;
# }
# #T_12446_row3_col2 {
#   background-color: #96fca7;
#   color: #000000;
# }
# #T_12446_row3_col3 {
#   background-color: #aef498;
#   color: #000000;
# }
# #T_12446_row4_col2 {
#   background-color: #a0faa1;
#   color: #000000;
# }
# #T_12446_row5_col0 {
#   background-color: #5e35fe;
#   color: #f1f1f1;
# }
# #T_12446_row5_col2 {
#   background-color: #42edd3;
#   color: #000000;
# }
# #T_12446_row5_col3 {
#   background-color: #50f4cc;
#   color: #000000;
# }
# #T_12446_row6_col1 {
#   background-color: #5af8c8;
#   color: #000000;
# }
# #T_12446_row7_col0 {
#   background-color: #0dc2e8;
#   color: #000000;
# }
# #T_12446_row7_col1 {
#   background-color: #37e6d8;
#   color: #000000;
# }
# #T_12446_row7_col2, #T_12446_row7_col3 {
#   background-color: #68fcc1;
#   color: #000000;
# }
# #T_12446_row8_col0 {
#   background-color: #ff9850;
#   color: #000000;
# }
# #T_12446_row8_col2 {
#   background-color: #ff8947;
#   color: #f1f1f1;
# }
# #T_12446_row8_col3 {
#   background-color: #ff4724;
#   color: #f1f1f1;
# }
# #T_12446_row9_col2 {
#   background-color: #6e1cff;
#   color: #f1f1f1;
# }
# #T_12446_row9_col3 {
#   background-color: #6a22fe;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_12446">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12446_level0_col0" class="col_heading level0 col0" >sepal_length</th>
#       <th id="T_12446_level0_col1" class="col_heading level0 col1" >sepal_width</th>
#       <th id="T_12446_level0_col2" class="col_heading level0 col2" >petal_length</th>
#       <th id="T_12446_level0_col3" class="col_heading level0 col3" >petal_width</th>
#       <th id="T_12446_level0_col4" class="col_heading level0 col4" >species</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12446_level0_row0" class="row_heading level0 row0" >127</th>
#       <td id="T_12446_row0_col0" class="data row0 col0" >6.100000</td>
#       <td id="T_12446_row0_col1" class="data row0 col1" >3.000000</td>
#       <td id="T_12446_row0_col2" class="data row0 col2" >4.900000</td>
#       <td id="T_12446_row0_col3" class="data row0 col3" >1.800000</td>
#       <td id="T_12446_row0_col4" class="data row0 col4" >Iris-virginica</td>
#     </tr>
#     <tr>
#       <th id="T_12446_level0_row1" class="row_heading level0 row1" >115</th>
#       <td id="T_12446_row1_col0" class="data row1 col0" >6.400000</td>
#       <td id="T_12446_row1_col1" class="data row1 col1" >3.200000</td>
#       <td id="T_12446_row1_col2" class="data row1 col2" >5.300000</td>
#       <td id="T_12446_row1_col3" class="data row1 col3" >2.300000</td>
#       <td id="T_12446_row1_col4" class="data row1 col4" >Iris-virginica</td>
#     </tr>
#     <tr>
#       <th id="T_12446_level0_row2" class="row_heading level0 row2" >12</th>
#       <td id="T_12446_row2_col0" class="data row2 col0" >4.800000</td>
#       <td id="T_12446_row2_col1" class="data row2 col1" >3.000000</td>
#       <td id="T_12446_row2_col2" class="data row2 col2" >1.400000</td>
#       <td id="T_12446_row2_col3" class="data row2 col3" >0.100000</td>
#       <td id="T_12446_row2_col4" class="data row2 col4" >Iris-setosa</td>
#     </tr>
#     <tr>
#       <th id="T_12446_level0_row3" class="row_heading level0 row3" >75</th>
#       <td id="T_12446_row3_col0" class="data row3 col0" >6.600000</td>
#       <td id="T_12446_row3_col1" class="data row3 col1" >3.000000</td>
#       <td id="T_12446_row3_col2" class="data row3 col2" >4.400000</td>
#       <td id="T_12446_row3_col3" class="data row3 col3" >1.400000</td>
#       <td id="T_12446_row3_col4" class="data row3 col4" >Iris-versicolor</td>
#     </tr>
#     <tr>
#       <th id="T_12446_level0_row4" class="row_heading level0 row4" >51</th>
#       <td id="T_12446_row4_col0" class="data row4 col0" >6.400000</td>
#       <td id="T_12446_row4_col1" class="data row4 col1" >3.200000</td>
#       <td id="T_12446_row4_col2" class="data row4 col2" >4.500000</td>
#       <td id="T_12446_row4_col3" class="data row4 col3" >1.500000</td>
#       <td id="T_12446_row4_col4" class="data row4 col4" >Iris-versicolor</td>
#     </tr>
#     <tr>
#       <th id="T_12446_level0_row5" class="row_heading level0 row5" >60</th>
#       <td id="T_12446_row5_col0" class="data row5 col0" >5.000000</td>
#       <td id="T_12446_row5_col1" class="data row5 col1" >2.000000</td>
#       <td id="T_12446_row5_col2" class="data row5 col2" >3.500000</td>
#       <td id="T_12446_row5_col3" class="data row5 col3" >1.000000</td>
#       <td id="T_12446_row5_col4" class="data row5 col4" >Iris-versicolor</td>
#     </tr>
#     <tr>
#       <th id="T_12446_level0_row6" class="row_heading level0 row6" >118</th>
#       <td id="T_12446_row6_col0" class="data row6 col0" >7.700000</td>
#       <td id="T_12446_row6_col1" class="data row6 col1" >2.600000</td>
#       <td id="T_12446_row6_col2" class="data row6 col2" >6.900000</td>
#       <td id="T_12446_row6_col3" class="data row6 col3" >2.300000</td>
#       <td id="T_12446_row6_col4" class="data row6 col4" >Iris-virginica</td>
#     </tr>
#     <tr>
#       <th id="T_12446_level0_row7" class="row_heading level0 row7" >69</th>
#       <td id="T_12446_row7_col0" class="data row7 col0" >5.600000</td>
#       <td id="T_12446_row7_col1" class="data row7 col1" >2.500000</td>
#       <td id="T_12446_row7_col2" class="data row7 col2" >3.900000</td>
#       <td id="T_12446_row7_col3" class="data row7 col3" >1.100000</td>
#       <td id="T_12446_row7_col4" class="data row7 col4" >Iris-versicolor</td>
#     </tr>
#     <tr>
#       <th id="T_12446_level0_row8" class="row_heading level0 row8" >102</th>
#       <td id="T_12446_row8_col0" class="data row8 col0" >7.100000</td>
#       <td id="T_12446_row8_col1" class="data row8 col1" >3.000000</td>
#       <td id="T_12446_row8_col2" class="data row8 col2" >5.900000</td>
#       <td id="T_12446_row8_col3" class="data row8 col3" >2.100000</td>
#       <td id="T_12446_row8_col4" class="data row8 col4" >Iris-virginica</td>
#     </tr>
#     <tr>
#       <th id="T_12446_level0_row9" class="row_heading level0 row9" >11</th>
#       <td id="T_12446_row9_col0" class="data row9 col0" >4.800000</td>
#       <td id="T_12446_row9_col1" class="data row9 col1" >3.400000</td>
#       <td id="T_12446_row9_col2" class="data row9 col2" >1.600000</td>
#       <td id="T_12446_row9_col3" class="data row9 col3" >0.200000</td>
#       <td id="T_12446_row9_col4" class="data row9 col4" >Iris-setosa</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.describe().style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_885d8_row0_col0, #T_885d8_row0_col1, #T_885d8_row0_col2, #T_885d8_row0_col3 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_885d8_row1_col0, #T_885d8_row5_col0 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_885d8_row1_col1, #T_885d8_row1_col2, #T_885d8_row4_col1, #T_885d8_row5_col1, #T_885d8_row6_col1, #T_885d8_row7_col3 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_885d8_row1_col3, #T_885d8_row2_col2, #T_885d8_row2_col3, #T_885d8_row4_col2 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_885d8_row2_col0, #T_885d8_row2_col1, #T_885d8_row3_col2, #T_885d8_row3_col3, #T_885d8_row4_col3 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_885d8_row3_col0, #T_885d8_row5_col2 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_885d8_row3_col1, #T_885d8_row5_col3, #T_885d8_row6_col3 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_885d8_row4_col0, #T_885d8_row6_col2 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_885d8_row6_col0 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_885d8_row7_col0 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_885d8_row7_col1 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_885d8_row7_col2 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# </style>
# <table id="T_885d8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_885d8_level0_col0" class="col_heading level0 col0" >sepal_length</th>
#       <th id="T_885d8_level0_col1" class="col_heading level0 col1" >sepal_width</th>
#       <th id="T_885d8_level0_col2" class="col_heading level0 col2" >petal_length</th>
#       <th id="T_885d8_level0_col3" class="col_heading level0 col3" >petal_width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_885d8_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_885d8_row0_col0" class="data row0 col0" >150.000000</td>
#       <td id="T_885d8_row0_col1" class="data row0 col1" >150.000000</td>
#       <td id="T_885d8_row0_col2" class="data row0 col2" >150.000000</td>
#       <td id="T_885d8_row0_col3" class="data row0 col3" >150.000000</td>
#     </tr>
#     <tr>
#       <th id="T_885d8_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_885d8_row1_col0" class="data row1 col0" >5.843333</td>
#       <td id="T_885d8_row1_col1" class="data row1 col1" >3.054000</td>
#       <td id="T_885d8_row1_col2" class="data row1 col2" >3.758667</td>
#       <td id="T_885d8_row1_col3" class="data row1 col3" >1.198667</td>
#     </tr>
#     <tr>
#       <th id="T_885d8_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_885d8_row2_col0" class="data row2 col0" >0.828066</td>
#       <td id="T_885d8_row2_col1" class="data row2 col1" >0.433594</td>
#       <td id="T_885d8_row2_col2" class="data row2 col2" >1.764420</td>
#       <td id="T_885d8_row2_col3" class="data row2 col3" >0.763161</td>
#     </tr>
#     <tr>
#       <th id="T_885d8_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_885d8_row3_col0" class="data row3 col0" >4.300000</td>
#       <td id="T_885d8_row3_col1" class="data row3 col1" >2.000000</td>
#       <td id="T_885d8_row3_col2" class="data row3 col2" >1.000000</td>
#       <td id="T_885d8_row3_col3" class="data row3 col3" >0.100000</td>
#     </tr>
#     <tr>
#       <th id="T_885d8_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_885d8_row4_col0" class="data row4 col0" >5.100000</td>
#       <td id="T_885d8_row4_col1" class="data row4 col1" >2.800000</td>
#       <td id="T_885d8_row4_col2" class="data row4 col2" >1.600000</td>
#       <td id="T_885d8_row4_col3" class="data row4 col3" >0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_885d8_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_885d8_row5_col0" class="data row5 col0" >5.800000</td>
#       <td id="T_885d8_row5_col1" class="data row5 col1" >3.000000</td>
#       <td id="T_885d8_row5_col2" class="data row5 col2" >4.350000</td>
#       <td id="T_885d8_row5_col3" class="data row5 col3" >1.300000</td>
#     </tr>
#     <tr>
#       <th id="T_885d8_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_885d8_row6_col0" class="data row6 col0" >6.400000</td>
#       <td id="T_885d8_row6_col1" class="data row6 col1" >3.300000</td>
#       <td id="T_885d8_row6_col2" class="data row6 col2" >5.100000</td>
#       <td id="T_885d8_row6_col3" class="data row6 col3" >1.800000</td>
#     </tr>
#     <tr>
#       <th id="T_885d8_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_885d8_row7_col0" class="data row7 col0" >7.900000</td>
#       <td id="T_885d8_row7_col1" class="data row7 col1" >4.400000</td>
#       <td id="T_885d8_row7_col2" class="data row7 col2" >6.900000</td>
#       <td id="T_885d8_row7_col3" class="data row7 col3" >2.500000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.shape
# Out:
# (150, 5)

# %%
df.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 3

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
plt.figure(figsize = (12, 8))
df.plot()
plt.show()

# %%
c1 = 'sepal_length'
plt.figure(figsize = (12, 8))
df[c1].hist()
plt.title(c1, fontsize=18)
plt.show()

# %%
c2 = 'sepal_width'
plt.figure(figsize = (12, 8))
df[c2].hist()
plt.title(c2, fontsize=18)
plt.show()

# %%
c3 = 'petal_length'
plt.figure(figsize = (12, 8))
df[c3].hist()
plt.title(c3, fontsize=18)
plt.show()

# %%
c4 = 'petal_width'
plt.figure(figsize = (12, 8))
df[c4].hist()
plt.title(c4, fontsize=18)
plt.show()

# %%
sns.pairplot(df , hue = ("species"))

# %% [markdown]
# Encoding categorical values

# %%
le = LabelEncoder()

# %%
df['species'] = le.fit_transform(df['species'])

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [147 rows x 5 columns]

# %%
df['species'].unique()
# Out:
# array([0, 1, 2])

# %%
X = df.drop(['species'], axis=1)
Y = df['species']

# %%
#X
X.shape
# Out:
# (147, 4)

# %%
#Y
Y.shape
# Out:
# (147,)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size= 0.25 )

# %%
X_train.shape
# Out:
# (110, 4)

# %%
X_test.shape
# Out:
# (37, 4)

# %%
Y_train.shape
# Out:
# (110,)

# %%
Y_test.shape
# Out:
# (37,)

# %% [markdown]
# # Modelling

# %% [markdown]
# # LogisticRegression

# %%
Lo_model=LogisticRegression(max_iter= 100)

# %%
Lo_model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
pred = Lo_model.predict(X_test)
print('Accuracy:', accuracy_score(pred,Y_test))
# Out:
# Accuracy: 0.9459459459459459

# %%
confusion = confusion_matrix(Y_test, pred)
print ("Confusion matrix:\n" ,confusion)
print(classification_report(Y_test,pred))
# Out:
# Confusion matrix:
#  [[16  0  0]
#  [ 0 12  2]
#  [ 0  0  7]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.86      0.92        14
#            2       0.78      1.00      0.88         7
#
#     accuracy                           0.95        37
#    macro avg       0.93      0.95      0.93        37
# weighted avg       0.96      0.95      0.95        37

# %% [markdown]
# # KNN

# %%
KNN_model = KNeighborsClassifier(n_neighbors = 4)
KNN_model.fit(X_train,Y_train)
y_pred2 = KNN_model.predict(X_test)

print('Accuracy:', accuracy_score(Y_test, y_pred2))
# Out:
# Accuracy: 0.9459459459459459

# %% [markdown]
# # DecisionTree

# %%
dt_model = tree.DecisionTreeClassifier()
dt_model.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dt = dt_model.predict(X_test)

# %%
acc_dt = accuracy_score(Y_test, pred_dt)
#print('Accuracy:', accuracy_score(Y_test,pred_dt))

# %%
acc_dt
# Out:
# 0.9459459459459459

# %% [markdown]
# # The End
# Thank for reading my analysis , if you any questions or advice me please write in the comment

# %% [markdown]
# # Vote
# If you liked my workvote me
